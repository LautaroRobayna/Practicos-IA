# %% [markdown]
# ## Práctico 3: Frozen Lake

# %% [markdown]
# ### Dependencias

# %%
import gymnasium
from gymnasium.envs.toy_text.frozen_lake import generate_random_map
from model import Model
from main import main

# %% [markdown]
# ### Probando el ambiente

# %% [markdown]
# Recomendamos comentar esta parte cuando ejecuten UCS y A*

# %%
env = gymnasium.make(
            "FrozenLake-v1",
            desc=generate_random_map(size=4), # genera un mapa aleatorio de dimension 4x4
            is_slippery=False, # probabilidad 0 de resbalar (100% determinista)
            render_mode="human", # muestra el entorno en pantalla
        )

# %% [markdown]
# Action Space y Observation Space

# %%
print("Action Space: ", env.action_space)
print("Observation Space: ", env.observation_space)

print("Accion aleatoria: ", env.action_space.sample())
print("Observacion aleatoria: ", env.observation_space.sample())
# Out:
# Action Space:  Discrete(4)
# Observation Space:  Discrete(16)
# Accion aleatoria:  0
# Observacion aleatoria:  15

# %% [markdown]
# Imprimir el laberinto

# %%
print(env.unwrapped.desc)
# Out:
# [[b'S' b'H' b'F' b'F']
#  [b'F' b'F' b'F' b'F']
#  [b'H' b'F' b'F' b'F']
#  [b'F' b'H' b'F' b'G']]

# %% [markdown]
# Jugando aleatoriamente

# %%
done = False
env.reset()
env.render()

while not done:
    action = env.action_space.sample()
    observation, reward, done, _, _ = env.step(action)
    env.render()
# Out:
# /home/lautaro/Documentos/Facultad/Semestre 7/IA/Practicos-IA/Practico3 - Algorimos de busqueda/.venv/lib/python3.10/site-packages/pygame/pkgdata.py:25: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import resource_stream, resource_exists

# %% [markdown]
# ### Utilizando el modelo del ambiente

# %%
model = Model(env.unwrapped.desc)
model.graph
# Out:
# {0: {2: 1, 0: 0, 3: 0, 1: 4},
#  1: {},
#  2: {2: 3, 0: 1, 3: 2, 1: 6},
#  3: {2: 3, 0: 2, 3: 3, 1: 7},
#  4: {2: 5, 0: 4, 3: 0, 1: 8},
#  5: {2: 6, 0: 4, 3: 1, 1: 9},
#  6: {2: 7, 0: 5, 3: 2, 1: 10},
#  7: {2: 7, 0: 6, 3: 3, 1: 11},
#  8: {},
#  9: {2: 10, 0: 8, 3: 5, 1: 13},
#  10: {2: 11, 0: 9, 3: 6, 1: 14},
#  11: {2: 11, 0: 10, 3: 7, 1: 15},
#  12: {2: 13, 0: 12, 3: 8, 1: 12},
#  13: {},
#  14: {2: 15, 0: 13, 3: 10, 1: 14},
#  15: {}}

# %% [markdown]
# Obtener las posiciones *x* e *y* de un estado

# %%
n = env.unwrapped.desc.shape[0]
state = 12
x_state = state % n
y_state = state // n

print("El estado es: ", state, " y sus coordenadas son: ", x_state, y_state)
# Out:
# El estado es:  12  y sus coordenadas son:  0 3

# %% [markdown]
# ### Ejecutar Main

# %%
from main import main

main()
# Out:
# Iniciando comparacion de agentes de busqueda
# ============================================================
#
# Probando en ambiente: 4x4
# ----------------------------------------
#   Ejecutando UCS...
#     Exito - Pasos: 6, Tiempo: 3.644s
#   Ejecutando A*...
#     Exito - Pasos: 6, Tiempo: 3.252s
#
# Probando en ambiente: 8x8
# ----------------------------------------
#   Ejecutando UCS...
#     Exito - Pasos: 14, Tiempo: 0.006s
# /home/lautaro/Documentos/Facultad/Semestre 7/IA/Practicos-IA/Practico3 - Algorimos de busqueda/.venv/lib/python3.10/site-packages/gymnasium/envs/toy_text/frozen_lake.py:328: UserWarning: WARN: You are calling render method without specifying any render mode. You can specify the render_mode at initialization, e.g. gym.make("FrozenLake-v1", render_mode="rgb_array")
#   gym.logger.warn(
#   Ejecutando A*...
#     Exito - Pasos: 14, Tiempo: 0.002s
#
# Probando en ambiente: 16x16
# ----------------------------------------
#   Ejecutando UCS...
#     Exito - Pasos: 30, Tiempo: 0.009s
#   Ejecutando A*...
#     Exito - Pasos: 30, Tiempo: 0.004s
#
# RESUMEN DE RESULTADOS
# ============================================================
#
# 4x4:
#   UCS: OK - 6 pasos, 3.644s
#   A*: OK - 6 pasos, 3.252s
#
# 8x8:
#   UCS: OK - 14 pasos, 0.006s
#   A*: OK - 14 pasos, 0.002s
#
# 16x16:
#   UCS: OK - 30 pasos, 0.009s
#   A*: OK - 30 pasos, 0.004s
#
# ============================================================
# COMPARACION DE AGENTES
# ============================================================
#
# 4x4:
#   UCS:  6 pasos, 3.644s
#   A*:   6 pasos, 3.252s
#   -> A* es mejor (mismo pasos, menos tiempo)
#
# 8x8:
#   UCS:  14 pasos, 0.006s
#   A*:   14 pasos, 0.002s
#   -> A* es mejor (mismo pasos, menos tiempo)
#
# 16x16:
#   UCS:  30 pasos, 0.009s
#   A*:   30 pasos, 0.004s
#   -> A* es mejor (mismo pasos, menos tiempo)
